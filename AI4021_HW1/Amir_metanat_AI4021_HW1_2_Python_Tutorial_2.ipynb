# %% [markdown]
# Problem 1:Create a NumPy array of 20 random integers between 1 and 100. Calculate the mean, median, and standard deviation of the array.

# %%
import numpy as np

arry_random = np.random.randint(1,101,20)

mean = np.mean(arry_random)
median = np.median(arry_random)
std_deviation = np.std(arry_random)

print("arry random:" , arry_random)
print("mean:", mean)
print("median:" , median)
print("std_deviation:" , std_deviation)
# Out:
# arry random: [13 39 65  9 75 99 98 35 78 47  3 40 32 71 12 33  7 50 79 63]
# mean: 47.4
# median: 43.5
# std_deviation: 29.3894538908092

# %% [markdown]
# **Problem 2:** Create a Pandas DataFrame with three columns - 'Name', 'Age', and 'City' - and at least five rows of data. Perform a basic data exploration by displaying the first 3 rows, the last 2 rows, and a summary of statistics for the 'Age' column.

# %%
import pandas as pd

data = {
    'name': ['amir' , 'ali' , 'reza','mohamad', 'javad' ],
    'age': [35,55,45,25,42],
    'city':['qazvin','tehran','mashhad','tabriz','ahvaz']

}

df = pd.DataFrame(data)

print("frist 3 rows:")
print(df.head(3))
print("last 2 rows:" )
print(df.tail(2))

print("summary of age column:", df['age'].describe())
print("summary of age column" , df['name'].describe())
# Out:
# frist 3 rows:
#    name  age     city
# 0  amir   35   qazvin
# 1   ali   55   tehran
# 2  reza   45  mashhad
# last 2 rows:
#       name  age    city
# 3  mohamad   25  tabriz
# 4    javad   42   ahvaz
# summary of age column: count     5.00000
# mean     40.40000
# std      11.21606
# min      25.00000
# 25%      35.00000
# 50%      42.00000
# 75%      45.00000
# max      55.00000
# Name: age, dtype: float64
# summary of age column count        5
# unique       5
# top       amir
# freq         1
# Name: name, dtype: object

# %% [markdown]
# **Problem 3:** Create a bar chart using Matplotlib to visualize the following data: Monthly sales for a store (January to May). Use appropriate labels and titles for the chart.

# %%
import matplotlib.pyplot as plt

months = ['January', 'February', 'March', 'April', 'May']
sales = [60000,25000,75000,40000,33000]

plt.figure(figsize=(6,4))
plt.bar(months,sales,color='red')

plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales for the Store (January to May)')

plt.show()

# %% [markdown]
# **Problem 4:** Create two NumPy arrays, 'arr1' and 'arr2', both of size 5x5 with random integer values. Perform element-wise addition, subtraction, multiplication, and division between the two arrays.

# %%
import numpy as np

arry1 = np.random.randint(1,100,(5,5))
arry2 = np.random.randint(1,100,(5,5))

addition = arry1 + arry2
subtraction = arry1 - arry2
multiplication = arry1 * arry2
division = np.divide(arry1, arry2, out=np.zeros_like(arry1, dtype=np.float64), where=arry2 != 0)

print("Array 1:")
print(arry1)
print("\nArray 2:")
print(arry2)
print("Addition:")
print(addition)
print("Subtraction:")
print(subtraction)
print("Multiplication:")
print(multiplication)
print("Division:")
print(division)
# Out:
# Array 1:
# [[25  8 93 82 45]
#  [38 75 83 81 71]
#  [66 44  9 44 46]
#  [85 19 81 83 62]
#  [83 97 62 25 90]]
#
# Array 2:
# [[ 7 60 16 62 52]
#  [ 4 29 81 28 87]
#  [17 78 36 91  8]
#  [ 2 81 87 21 18]
#  [90 92 49 53 62]]
# Addition:
# [[ 32  68 109 144  97]
#  [ 42 104 164 109 158]
#  [ 83 122  45 135  54]
#  [ 87 100 168 104  80]
#  [173 189 111  78 152]]
# Subtraction:
# [[ 18 -52  77  20  -7]
#  [ 34  46   2  53 -16]
#  [ 49 -34 -27 -47  38]
#  [ 83 -62  -6  62  44]
#  [ -7   5  13 -28  28]]
# Multiplication:
# [[ 175  480 1488 5084 2340]
#  [ 152 2175 6723 2268 6177]
#  [1122 3432  324 4004  368]
#  [ 170 1539 7047 1743 1116]
#  [7470 8924 3038 1325 5580]]
# Division:
# [[ 3.57142857  0.13333333  5.8125      1.32258065  0.86538462]
#  [ 9.5         2.5862069   1.02469136  2.89285714  0.81609195]
#  [ 3.88235294  0.56410256  0.25        0.48351648  5.75      ]
#  [42.5         0.2345679   0.93103448  3.95238095  3.44444444]
#  [ 0.92222222  1.05434783  1.26530612  0.47169811  1.4516129 ]]

# %% [markdown]
# **Problem 5:** Given a Pandas DataFrame with information about employees, filter and display only the employees who are older than 30 years.

# %%
import pandas as pd

data = {
    'name': ['amir' , 'ali' , 'reza','mohamad', 'javad'],
    'age': [21, 32, 48, 38, 18],
    'department': ['HR', 'IT', 'Finance', 'IT', 'Marketing']
}

df_employe = pd.DataFrame(data)

older_than_30 = df_employe[df_employe['age'] > 30 ]
print(older_than_30)
# Out:
#       name  age department
# 1      ali   32         IT
# 2     reza   48    Finance
# 3  mohamad   38         IT

# %% [markdown]
# **Problem 6:** Create a scatter plot using Matplotlib to visualize a dataset of 100 random (x, y) coordinates. Label the axes appropriately and give the plot a title.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
x = np.random.rand(100)
y = np.random.rand(100)

plt.figure(figsize=(6,3))
plt.scatter(x, y, c='r', marker='^', label='Random Data')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot of 100 Random (x, y) Coordinates')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Problem 7:** Create two NumPy matrices, 'matrix1' (2x3) and 'matrix2' (3x4), with random values. Perform matrix multiplication between the two matrices.

# %%
import numpy as np

matrix1 = np.random.rand(2,3)
matrix2 = np.random.rand(3,4)

result_matrix = np.dot(matrix1,matrix2)

print("matrix1 (2x3):")
print(matrix1)
print("matrix2 (3x4):")
print(matrix2)
print(" Multiplication Result:")
print(result_matrix)
# Out:
# matrix1 (2x3):
# [[0.58831711 0.83104846 0.62898184]
#  [0.87265066 0.27354203 0.79804683]]
# matrix2 (3x4):
# [[0.18563594 0.95279166 0.68748828 0.21550768]
#  [0.94737059 0.73085581 0.25394164 0.21331198]
#  [0.51820071 0.02566272 0.20747008 0.42468547]]
#  Multiplication Result:
# [[1.22246251 1.18406161 0.74599384 0.57117889]
#  [0.83468945 1.0518541  0.83497165 0.5853316 ]]

# %% [markdown]
# **Problem 8:** Given a Pandas DataFrame containing sales data, calculate and display the total sales for each product category.

# %%
import pandas as pd

data = {
    'Product_Category': ['olive', 'Pickle', 'olive', 'Pickle', 'olive'],
    'Sales': [2500,1800, 1500, 1700, 1600]
 }

sales_df = pd.DataFrame(data)

total_sales_by_category = sales_df.groupby('Product_Category')['Sales'].sum()
print(total_sales_by_category)
# Out:
# Product_Category
# Pickle    3500
# olive     5600
# Name: Sales, dtype: int64

# %% [markdown]
# **Problem 9:** Create a line chart using Matplotlib to visualize the population growth of a city over 10 years. Label the axes and provide a title.

# %%
import matplotlib.pyplot as plt


years = range(1, 11)
population = [10000, 12000, 15000, 18000, 22000, 26000, 31000, 36000, 42000, 50000]


plt.figure(figsize=(7, 5))
plt.plot(years, population, marker='o', color='b', linestyle='-', linewidth=2, markersize=8)


plt.xlabel('Years')
plt.ylabel('Population')
plt.title('Population Growth of a City Over 10 Years')


plt.grid()
plt.show()

# %% [markdown]
# **Problem 10:** Given a Pandas DataFrame containing information about students, add a new column 'Grade' based on the following criteria:
# * If 'Score' >= 90, Grade is 'A'
# * If 'Score' >= 80, Grade is 'B'
# * If 'Score' >= 70, Grade is 'C'
# * If 'Score' < 70, Grade is 'D'

# %%
import pandas as pd

data = {
    'StudentName': ['Amir', 'Reza', 'AmirAli', 'AmirReza', 'ehsan'],
    'Score': [65, 85, 95, 60, 55]
}

df_student = pd.DataFrame(data)


df_student['Grade'] = 'D'

df_student.loc[df_student['Score'] >= 90, 'Grade'] = 'A'
df_student.loc[(df_student['Score'] >= 80) & (df_student['Score'] < 90), 'Grade'] = 'B'
df_student.loc[(df_student['Score'] >= 70) & (df_student['Score'] < 80), 'Grade'] = 'C'


print(df_student)
# Out:
#   StudentName  Score Grade
# 0        Amir     65     D
# 1        Reza     85     B
# 2     AmirAli     95     A
# 3    AmirReza     60     D
# 4       ehsan     55     D

# %% [markdown]
# **Problem 11:** You are given a dataset containing monthly sales data for three products (A, B, and C) over a two-year period. Your task is to perform various data analysis tasks using NumPy, Pandas, and Matplotlib.
#
#
# *   Dataset:
#
# ```
# import pandas as pd
#
# data = {
#     'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
#     'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
#     'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
#     'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
# }
#
# sales_df = pd.DataFrame(data)
# ```
# *  Tasks:
# 1. Calculate and display the total sales for each product over the two-year period.
#
# 2. Calculate and display the average monthly sales for each product.
#
# 3. Find the month with the highest sales for each product, and display the product and the sales value for that month.
#
# 4. Calculate and display the percentage change in sales for each product from January to December in the second year (2022).
#
# 5. Create a line chart using Matplotlib to visualize the monthly sales data for each product over the two-year period. Label the axes and provide a title for the chart.
#
# 6. Calculate the correlation between Product A and Product B sales. Is there a strong correlation between these two products? Display the correlation coefficient.

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {
    'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
    'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
    'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
    'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
}

sales_df = pd.DataFrame(data)


total_sales = sales_df.sum(numeric_only=True)
print("Task 1: Total Sales for Each Product")
print(total_sales)


average_sales = sales_df.mean(numeric_only=True)
print("\nTask 2: Average Monthly Sales for Each Product")
print(average_sales)


max_sales_month = sales_df.set_index('Month').idxmax()
max_sales = sales_df.set_index('Month').max()
print("\nTask 3: Month with the Highest Sales for Each Product")
highest_sales = pd.DataFrame({'Product': max_sales_month, 'Sales': max_sales})
print(highest_sales)


sales_january_2022 = sales_df.loc[13, 'Product A Sales':'Product C Sales']
sales_december_2022 = sales_df.loc[23, 'Product A Sales':'Product C Sales']
percentage_change = (sales_december_2022 - sales_january_2022) / sales_january_2022 * 100
print("\nTask 4: Percentage Change in Sales from January to December in 2022")
print(percentage_change)

plt.figure(figsize=(10, 5))
for product in ['Product A Sales', 'Product B Sales', 'Product C Sales']:
    plt.plot(sales_df['Month'], sales_df[product], label=product.split()[-2], marker='s')


plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales Data for Each Product Over Two Years')
plt.legend()
plt.grid(True)
plt.show()


correlation = sales_df['Product A Sales'].corr(sales_df['Product B Sales'])
print("\nTask 6: Correlation between Product A and Product B Sales")
print("Correlation Coefficient:", correlation)
# Out:
# Task 1: Total Sales for Each Product
# Product A Sales    31600
# Product B Sales    23800
# Product C Sales    11510
# dtype: int64
#
# Task 2: Average Monthly Sales for Each Product
# Product A Sales    1316.666667
# Product B Sales     991.666667
# Product C Sales     479.583333
# dtype: float64
#
# Task 3: Month with the Highest Sales for Each Product
#                    Product  Sales
# Product A Sales 2022-12-31   1900
# Product B Sales 2022-12-31   1700
# Product C Sales 2022-12-31    720
#
# Task 4: Percentage Change in Sales from January to December in 2022
# Product A Sales        18.75
# Product B Sales    54.545455
# Product C Sales    38.461538
# dtype: object
# Task 6: Correlation between Product A and Product B Sales
# Correlation Coefficient: 0.954652710589704
